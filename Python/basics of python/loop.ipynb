# %% [markdown]
# for loop

# %%
# for loop
for i in range(3):
    print('hello')
# Out:
# hello
# hello
# hello

# %%
# for loop for list
names:list[str] = ['yash','abhi','narendar','rahul']

for names in names:
    print(f'hello {names}')
    print('....')

# %% [markdown]
# while loop

# %%
i:int = 0
while i <= 3:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3

# %%
value: int = int(input())
if value < 10:
    print(f'the value is less than 10 which is {value}')
elif value > 10:
    print(f'the value = {value} is more than 10')
else:
    print('the value is 10')
# Out:
#  23
# the value = 23 is more than 10
