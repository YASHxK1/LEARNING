# %% [markdown]
# example 1

# %%
def func()-> None:
    print('hello')

func()
func() 
func() 
func()
# Out:
# hello
# hello
# hello
# hello

# %% [markdown]
# Example 2 using parameters

# %%
def add(a:float,b:float) -> float:
    print(f'Adding: {a} + {b}')
    int = a+b
    return int

print(add(10,15))
print(add(12,23))
# Out:
# Adding: 10 + 15
# 25
# Adding: 12 + 23
# 35

# %% [markdown]
# Example 3 using default paramerers

# %%
def greeet(name: str,greeting:str = 'hi')-> None:
    print(f'{greeting},{name}')

greeet('yash')
# Out:
# hi,yash
