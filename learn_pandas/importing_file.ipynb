# %%
import pandas as pd

# %%
df=pd.read_csv("E:/Jupyter_notebook/learn_pandas/pokemon.csv")
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass    Poison     1.0    13.0          0
# 2      3    Venusaur     Grass    Poison     2.0   100.0          0
# 3      4  Charmander      Fire       NaN     0.6     8.5          0
# 4      5  Charmeleon      Fire       NaN     1.1    19.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 6      7    Squirtle     Water       NaN     0.5     9.0          0
# 7      8   Wartortle     Water       NaN     1.0    22.5          0
# 8      9   Blastoise     Water       NaN     1.6    85.5          0
# 9     10    Caterpie       Bug       NaN     0.3     2.9          0
# 10    11     Metapod       Bug       NaN     0.7     9.9          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# ...

# %%
df = pd.read_json("E:/Jupyter_notebook/learn_pandas/pokemon.json")

# %%
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire    None     0.6     8.5          0
# 4      5  Charmeleon     Fire    None     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon    None     1.8     3.3          0
# 147  148   Dragonair   Dragon    None     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic    None     2.0   122.0          1
#
# [150 rows x 7 columns]

# %% [markdown]
# ## selectionby columns

# %%
#print(df['Name'].to_string())
#print(df['Height'].to_string())
print(df[['Name','Height','Weight']].to_string())
# Out:
#            Name  Height  Weight
# 0     Bulbasaur     0.7     6.9
# 1       Ivysaur     1.0    13.0
# 2      Venusaur     2.0   100.0
# 3    Charmander     0.6     8.5
# 4    Charmeleon     1.1    19.0
# 5     Charizard     1.7    90.5
# 6      Squirtle     0.5     9.0
# 7     Wartortle     1.0    22.5
# 8     Blastoise     1.6    85.5
# 9      Caterpie     0.3     2.9
# 10      Metapod     0.7     9.9
# 11   Butterfree     1.1    32.0
# 12       Weedle     0.3     3.2
# 13       Kakuna     0.6    10.0
# 14     Beedrill     1.0    29.5
# 15       Pidgey     0.3     1.8
# 16    Pidgeotto     1.1    30.0
# 17      Pidgeot     1.5    39.5
# 18      Rattata     0.3     3.5
# 19     Raticate     0.7    18.5
# 20      Spearow     0.3     2.0
# 21       Fearow     1.2    38.0
# 22        Ekans     2.0     6.9
# 23        Arbok     3.5    65.0
# 24      Pikachu     0.4     6.0
# 25       Raichu     0.8    30.0
# 26    Sandshrew     0.6    12.0
# 27    Sandslash     1.0    29.5
# ...

# %% [markdown]
# ## selection by rows

# %%
print(df.loc[])
# Out:
# No              46
# Name         Paras
# Type1          Bug
# Type2        Grass
# Height         0.3
# Weight         5.4
# Legendary        0
# Name: 45, dtype: object

# %% [markdown]
# # Unsing Name as Index (custom index)

# %% [markdown]
# ### selection by rows

# %%
df_csv =pd.read_csv("E:/Jupyter_notebook/learn_pandas/pokemon.csv",index_col='Name')
print(df_csv)
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
print(df_csv.loc['Charmeleon'])
print("---------------------")
print(df_csv.loc['Bulbasaur'])
# Out:
# No              5
# Type1        Fire
# Type2         NaN
# Height        1.1
# Weight       19.0
# Legendary       0
# Name: Charmeleon, dtype: object
# ---------------------
# No                1
# Type1         Grass
# Type2        Poison
# Height          0.7
# Weight          6.9
# Legendary         0
# Name: Bulbasaur, dtype: object

# %%
print(df_csv.loc['Bulbasaur':'Paras',['Height','Weight']])#selection by range
# Out:
#             Height  Weight
# Name
# Bulbasaur      0.7     6.9
# Ivysaur        1.0    13.0
# Venusaur       2.0   100.0
# Charmander     0.6     8.5
# Charmeleon     1.1    19.0
# Charizard      1.7    90.5
# Squirtle       0.5     9.0
# Wartortle      1.0    22.5
# Blastoise      1.6    85.5
# Caterpie       0.3     2.9
# Metapod        0.7     9.9
# Butterfree     1.1    32.0
# Weedle         0.3     3.2
# Kakuna         0.6    10.0
# Beedrill       1.0    29.5
# Pidgey         0.3     1.8
# Pidgeotto      1.1    30.0
# Pidgeot        1.5    39.5
# Rattata        0.3     3.5
# Raticate       0.7    18.5
# Spearow        0.3     2.0
# Fearow         1.2    38.0
# Ekans          2.0     6.9
# Arbok          3.5    65.0
# Pikachu        0.4     6.0
# Raichu         0.8    30.0
# Sandshrew      0.6    12.0
# Sandslash      1.0    29.5
# Nidoran♀       0.4     7.0
# Nidorina       0.8    20.0
# Nidoqueen      1.3    60.0
# Nidoran♂       0.5     9.0
# Nidorino       0.9    19.5
# ...

# %%
print(df_csv.iloc[0:11,0:3])#selection by range
# Out:
#             No  Type1   Type2
# Name
# Bulbasaur    1  Grass  Poison
# Ivysaur      2  Grass  Poison
# Venusaur     3  Grass  Poison
# Charmander   4   Fire     NaN
# Charmeleon   5   Fire     NaN
# Charizard    6   Fire  Flying
# Squirtle     7  Water     NaN
# Wartortle    8  Water     NaN
# Blastoise    9  Water     NaN
# Caterpie    10    Bug     NaN
# Metapod     11    Bug     NaN

# %%
pokemon = input("Enter Pokemon Name: ")
try:
    print(df_csv.loc[pokemon])
    #print(df_csv.loc['Charmeleon'])
except KeyError as e: 
    print(f"{pokemon}not found")
# Out:
# Enter Pokemon Name:  Charmeleon
# No              5
# Type1        Fire
# Type2         NaN
# Height        1.1
# Weight       19.0
# Legendary       0
# Name: Charmeleon, dtype: object
