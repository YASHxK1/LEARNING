# %%
import pandas as pd

# %% [markdown]
# ## Data frame

# %%
data = {"Name":['yash','narendar','rahul'],
       "age":[30,35,50]
       }

# %%
df=pd.DataFrame(data)
print(df)
print("------------------------")
df=pd.DataFrame(data,index=['Emp 1 = ','Emp 2 = ','emp 3 ='])
print(df)
# Out:
#        Name  age
# 0      yash   30
# 1  narendar   35
# 2     rahul   50
# ------------------------
#               Name  age
# Emp 1 =       yash   30
# Emp 2 =   narendar   35
# emp 3 =      rahul   50

# %%
print(df.loc['Emp 2 = '])
# Out:
# Name    narendar
# age           35
# Name: Emp 2 = , dtype: object

# %%
print(df.iloc[1])
# Out:
# Name    narendar
# age           35
# Name: Emp 2 = , dtype: object

# %%
#add new col
df["job"]=["cook","N/A","cash"]
print(df)
# Out:
#               Name  age   job
# Emp 1 =       yash   30  cook
# Emp 2 =   narendar   35   N/A
# emp 3 =      rahul   50  cash

# %%
#add new row
new_row=pd.DataFrame([{"Neme":"Sandy","Age":28,"job":"cleaner"}])
df=pd.appand([df,new_row])
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 #add new row
#       2 new_row=pd.DataFrame([{"Neme":"Sandy","Age":28,"job":"cleaner"}])
# ----> 3 df=pd.appand([df,new_row])
#       4 print(df)
#
# AttributeError: module 'pandas' has no attribute 'appand'

# %%
data = {
"Name": ["Spongebob", "Patrick", "Squidward"],
"Age": [30, 35, 50]
}
df = pd.DataFrame (data, index=["Employee 1", "Employee 2", "Employee 3"])
# Add a new column
df["Job"] = ["Cook", "N/A", "Cashier"]
# Add a new row
new_row = pd.DataFrame([{"Name": "Sandy", "Age": 28, "Job": "Engineer"},
                       {"Name": "Sandy", "Age": 28, "Job": "Engineer"}],
                      index=['emp 4 =','emp 5 ='])
df = pd.concat([df,new_row])
print(df)
# Out:
#                  Name  Age       Job
# Employee 1  Spongebob   30      Cook
# Employee 2    Patrick   35       N/A
# Employee 3  Squidward   50   Cashier
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer

# %%
new_row = pd.DataFrame([{"Name": "Sandy", "Age": 28, "Job": "Engineer"},
                       {"Name": "Sandy", "Age": 28, "Job": "Engineer"}],
                      index=['emp 4 =','emp 5 ='])
df = pd.concat([df,new_row])
print(df)
# Out:
#                  Name  Age       Job
# Employee 1  Spongebob   30      Cook
# Employee 2    Patrick   35       N/A
# Employee 3  Squidward   50   Cashier
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
# emp 4 =         Sandy   28  Engineer
# emp 5 =         Sandy   28  Engineer
